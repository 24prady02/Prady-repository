# %% [markdown]
# <a href="https://colab.research.google.com/github/24prady02/Prady-repository/blob/main/Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World
